# %% [markdown]
# Link for dataset: https://catalog.data.gov/dataset/nypd-arrests-data-historic

# %%
import altair as alt
import pandas as pd

# %%
df = pd.read_csv('NYPD_Arrests_Data__Historic_.csv')

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                               PD_DESC  \
# 0         236791704  11/22/2021  581.0                                   NaN
# 1         237354740  12/04/2021  153.0                                RAPE 3
# 2         236081433  11/09/2021  681.0            CHILD, ENDANGERING WELFARE
# 3          32311380  06/18/2007  511.0    CONTROLLED SUBSTANCE, POSSESSION 7
# 4         192799737  01/26/2019  177.0                          SEXUAL ABUSE
# ...             ...         ...    ...                                   ...
# 3818905    72449164  04/28/2010  725.0             FORGERY,M.V. REGISTRATION
# 3818906    72619224  05/09/2010  748.0                     CONTEMPT,CRIMINAL
# 3818907    72371794  04/23/2010  567.0           MARIJUANA, POSSESSION 4 & 5
# 3818908    72316959  04/20/2010  567.0           MARIJUANA, POSSESSION 4 & 5
# 3818909    72390410  04/25/2010  849.0  NY STATE LAWS,UNCLASSIFIED VIOLATION
#
# ...

# %%
df.dropna(inplace=True)

# %%
df['ARREST_BORO'] = df['ARREST_BORO'].replace({'M': 'Manhattan', 'B': 'Brooklyn', 'K': 'Bronx', 'S': 'Staten Island', 'Q': 'Queens'})

# %%
df.shape
# Out:
# (3794199, 19)

# %%
#use this to create a local CSV

df.to_csv('NY_Arrests.csv', index=False)
